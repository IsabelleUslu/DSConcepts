# %% [markdown]
# ## Introduction: This project visualizes recent earthquake activity in the Santorini region of Greece.
#
# Inspired by increased seismic activity observed in the area, the analysis maps earthquake locations and performs aggregations to provide an overview of the recent seismic trends
#
# Source = https://earthquake.usgs.gov/fdsnws/event/1/

# %%
import requests
import pandas as pd
import folium
from folium.plugins import HeatMap


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.width', 500)

# %%
start_time = 'now-180days' # Retreiving data for only 6 months
min_magnitude = 3
latitude = 39.1458
longitude = 34.1614
max_radius_km = 1500

# %%
url = requests.get(f'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_time}&minmagnitude={min_magnitude}&latitude={latitude}&longitude={longitude}&maxradiuskm={max_radius_km}')
dataset = url.json()

# %%
url
# Out:
# <Response [200]>

# %%
type(dataset)
# Out:
# dict

# %%
dataset
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1739245808000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=now-180days&minmagnitude=3&latitude=39.1458&longitude=34.1614&maxradiuskm=1500',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.14.1',
#   'count': 286},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '24 km SW of Amorgós, Greece',
#     'time': 1739242008807,
#     'updated': 1739242908040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pct8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pct8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000pct8',
#     'ids': ',us7000pct8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 1.551,
#     'rms': 0.63,
#     'gap': 101,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 24 km SW of Amorgós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6781, 36.7038, 10]},
#    'id': 'us7000pct8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '20 km E of Íos, Greece',
#     'time': 1739227864290,
#     'updated': 1739231711040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcse',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcse&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pcse',
#     'ids': ',us7000pcse,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 1.489,
#     'rms': 0.74,
#     'gap': 97,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 20 km E of Íos, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5085, 36.6927, 10]},
#    'id': 'us7000pcse'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '28 km NE of Oía, Greece',
#     'time': 1739227044695,
#     'updated': 1739235279373,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcs7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcs7&format=geojson',
#     'felt': 8,
#     'cdi': 7.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 406,
#     'net': 'us',
#     'code': '7000pcs7',
#     'ids': ',us7000pcs7,usauto7000pcs7,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,',
#     'nst': 118,
#     'dmin': 1.466,
#     'rms': 0.63,
#     'gap': 33,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 28 km NE of Oía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6213, 36.6318, 10]},
#    'id': 'us7000pcs7'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '24 km SW of Amorgós, Greece',
#     'time': 1739223455759,
#     'updated': 1739232999294,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcrr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcrr&format=geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000pcrr',
#     'ids': ',us7000pcrr,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 31,
#     'dmin': 1.528,
#     'rms': 0.65,
#     'gap': 104,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 24 km SW of Amorgós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.7381, 36.6549, 10]},
#    'id': 'us7000pcrr'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': '25 km SW of Amorgós, Greece',
#     'time': 1739218588890,
#     'updated': 1739230978177,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcr3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcr3&format=geojson',
#     'felt': 18,
#     'cdi': 6.6,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 428,
#     'net': 'us',
#     'code': '7000pcr3',
#     'ids': ',us7000pcr3,usauto7000pcr3,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,',
#     'nst': 111,
#     'dmin': 1.541,
#     'rms': 0.8,
#     'gap': 19,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.2 - 25 km SW of Amorgós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6758, 36.6944, 10]},
#    'id': 'us7000pcr3'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '31 km NE of Firá, Greece',
#     'time': 1739193274217,
#     'updated': 1739203725040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcmw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcmw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pcmw',
#     'ids': ',us7000pcmw,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 105,
#     'dmin': 1.468,
#     'rms': 0.93,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 31 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6911, 36.6065, 10]},
#    'id': 'us7000pcmw'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '25 km SW of Amorgós, Greece',
#     'time': 1739186597621,
#     'updated': 1739219072273,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcmg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcmg&format=geojson',
#     'felt': 2,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 355,
#     'net': 'us',
#     'code': '7000pcmg',
#     'ids': ',us7000pcmg,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 57,
#     'dmin': 1.533,
#     'rms': 0.92,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 25 km SW of Amorgós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6831, 36.6826, 10]},
#    'id': 'us7000pcmg'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '28 km NE of Firá, Greece',
#     'time': 1739149200958,
#     'updated': 1739149690040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pck7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pck7&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000pck7',
#     'ids': ',us7000pck7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 1.454,
#     'rms': 0.68,
#     'gap': 104,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 28 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6436, 36.6094, 10]},
#    'id': 'us7000pck7'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '122 km SW of Kýthira, Greece',
#     'time': 1739134514865,
#     'updated': 1739219746969,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcja',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcja&format=geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pcja',
#     'ids': ',us7000pcja,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 47,
#     'dmin': 1.926,
#     'rms': 0.64,
#     'gap': 138,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 122 km SW of Kýthira, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [22.1926, 35.2608, 43.73]},
#    'id': 'us7000pcja'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '25 km NE of Oía, Greece',
#     'time': 1739133341753,
#     'updated': 1739134382040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcj8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcj8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pcj8',
#     'ids': ',us7000pcj8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 55,
#     'dmin': 1.447,
#     'rms': 0.69,
#     'gap': 87,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 25 km NE of Oía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5758, 36.626, 10]},
#    'id': 'us7000pcj8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '17 km NE of Firá, Greece',
#     'time': 1739129499901,
#     'updated': 1739131116040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcip',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcip&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pcip',
#     'ids': ',us7000pcip,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 61,
#     'dmin': 1.359,
#     'rms': 0.57,
#     'gap': 98,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 17 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5565, 36.5372, 10]},
#    'id': 'us7000pcip'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '21 km NE of Firá, Greece',
#     'time': 1739129112419,
#     'updated': 1739130750040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcin',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcin&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pcin',
#     'ids': ',us7000pcin,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 62,
#     'dmin': 1.393,
#     'rms': 0.89,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 21 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6002, 36.5585, 10]},
#    'id': 'us7000pcin'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '12 km ENE of Mesariá, Greece',
#     'time': 1739128635388,
#     'updated': 1739196054040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcil',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcil&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000pcil',
#     'ids': ',us7000pcil,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 65,
#     'dmin': 1.281,
#     'rms': 0.45,
#     'gap': 110,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 12 km ENE of Mesariá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5708, 36.4461, 10]},
#    'id': 'us7000pcil'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '13 km NNE of Firá, Greece',
#     'time': 1739128603091,
#     'updated': 1739130349040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcij',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcij&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000pcij',
#     'ids': ',us7000pcij,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 73,
#     'dmin': 1.331,
#     'rms': 0.49,
#     'gap': 80,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 13 km NNE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5065, 36.5236, 10]},
#    'id': 'us7000pcij'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': '28 km WSW of Amorgós, Greece',
#     'time': 1739127938592,
#     'updated': 1739235743217,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcih',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcih&format=geojson',
#     'felt': 14,
#     'cdi': 7.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 426,
#     'net': 'us',
#     'code': '7000pcih',
#     'ids': ',us7000pcih,usauto7000pcih,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,',
#     'nst': 97,
#     'dmin': 1.529,
#     'rms': 0.8,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.2 - 28 km WSW of Amorgós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6236, 36.6992, 10]},
#    'id': 'us7000pcih'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '5 km ENE of Emporeío, Greece',
#     'time': 1739127237246,
#     'updated': 1739128746040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcid',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcid&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000pcid',
#     'ids': ',us7000pcid,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 74,
#     'dmin': 1.193,
#     'rms': 1.12,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 5 km ENE of Emporeío, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5003, 36.3749, 10]},
#    'id': 'us7000pcid'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '18 km NE of Firá, Greece',
#     'time': 1739126501829,
#     'updated': 1739134898040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcib',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcib&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pcib',
#     'ids': ',us7000pcib,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 57,
#     'dmin': 1.365,
#     'rms': 0.64,
#     'gap': 65,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 18 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5896, 36.5316, 10]},
#    'id': 'us7000pcib'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '25 km NE of Firá, Greece',
#     'time': 1739116527836,
#     'updated': 1739118979040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pchq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pchq&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pchq',
#     'ids': ',us7000pchq,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 25,
#     'dmin': 1.41,
#     'rms': 0.92,
#     'gap': 107,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 25 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6596, 36.5546, 10]},
#    'id': 'us7000pchq'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '21 km ENE of Firá, Greece',
#     'time': 1739114190674,
#     'updated': 1739116398040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pchj',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pchj&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pchj',
#     'ids': ',us7000pchj,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 1.368,
#     'rms': 1.09,
#     'gap': 104,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 21 km ENE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6341, 36.5178, 10]},
#    'id': 'us7000pchj'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '24 km NE of Firá, Greece',
#     'time': 1739088391244,
#     'updated': 1739096764040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcga',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcga&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pcga',
#     'ids': ',us7000pcga,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 1.419,
#     'rms': 1.02,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 24 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6324, 36.5754, 10]},
#    'id': 'us7000pcga'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '23 km NE of Oía, Greece',
#     'time': 1739077319317,
#     'updated': 1739084226040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcfe',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcfe&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pcfe',
#     'ids': ',us7000pcfe,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 38,
#     'dmin': 1.434,
#     'rms': 1.28,
#     'gap': 101,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 23 km NE of Oía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5453, 36.6225, 10]},
#    'id': 'us7000pcfe'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '27 km NE of Firá, Greece',
#     'time': 1739076452132,
#     'updated': 1739078548040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcf7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcf7&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pcf7',
#     'ids': ',us7000pcf7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 49,
#     'dmin': 1.427,
#     'rms': 1.33,
#     'gap': 91,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 27 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6761, 36.5667, 10]},
#    'id': 'us7000pcf7'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '10 km ENE of Mesariá, Greece',
#     'time': 1739069750291,
#     'updated': 1739074876040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcei',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcei&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000pcei',
#     'ids': ',us7000pcei,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 1.27,
#     'rms': 1.17,
#     'gap': 104,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 10 km ENE of Mesariá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5586, 36.4382, 10]},
#    'id': 'us7000pcei'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '7 km NNE of Firá, Greece',
#     'time': 1739064916442,
#     'updated': 1739130700607,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pce5',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pce5&format=geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000pce5',
#     'ids': ',us7000pce5,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 33,
#     'dmin': 1.278,
#     'rms': 1.28,
#     'gap': 100,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 7 km NNE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.4747, 36.4771, 10]},
#    'id': 'us7000pce5'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '24 km NE of Firá, Greece',
#     'time': 1739034913816,
#     'updated': 1739040036040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcch',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcch&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pcch',
#     'ids': ',us7000pcch,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 87,
#     'dmin': 1.418,
#     'rms': 0.66,
#     'gap': 105,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 24 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6139, 36.5816, 10]},
#    'id': 'us7000pcch'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '27 km NE of Firá, Greece',
#     'time': 1739033506892,
#     'updated': 1739045684040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pccc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pccc&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000pccc',
#     'ids': ',us7000pccc,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 39,
#     'dmin': 1.436,
#     'rms': 0.47,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 27 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6735, 36.5782, 10]},
#    'id': 'us7000pccc'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '29 km SW of Amorgós, Greece',
#     'time': 1739032198602,
#     'updated': 1739044264040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcc8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcc8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pcc8',
#     'ids': ',us7000pcc8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 99,
#     'dmin': 1.511,
#     'rms': 0.76,
#     'gap': 81,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 29 km SW of Amorgós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6277, 36.6788, 10]},
#    'id': 'us7000pcc8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '5 km ENE of Emporeío, Greece',
#     'time': 1739006642944,
#     'updated': 1739009033561,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcau',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcau&format=geojson',
#     'felt': 1,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000pcau',
#     'ids': ',us7000pcau,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 68,
#     'dmin': 1.192,
#     'rms': 1.3,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 5 km ENE of Emporeío, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.4977, 36.3756, 10]},
#    'id': 'us7000pcau'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '18 km E of Mesariá, Greece',
#     'time': 1739006148915,
#     'updated': 1739013918040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcaq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcaq&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pcaq',
#     'ids': ',us7000pcaq,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 1.262,
#     'rms': 0.8,
#     'gap': 88,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 18 km E of Mesariá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6486, 36.3919, 10]},
#    'id': 'us7000pcaq'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '17 km NE of Firá, Greece',
#     'time': 1739005806151,
#     'updated': 1739010445040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcan',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcan&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pcan',
#     'ids': ',us7000pcan,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 52,
#     'dmin': 1.366,
#     'rms': 1.03,
#     'gap': 82,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 17 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5645, 36.5418, 10]},
#    'id': 'us7000pcan'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '13 km NE of Mesariá, Greece',
#     'time': 1739005240940,
#     'updated': 1739042826382,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcah',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcah&format=geojson',
#     'felt': 1,
#     'cdi': 5.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 401,
#     'net': 'us',
#     'code': '7000pcah',
#     'ids': ',us7000pcah,usauto7000pcah,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,internal-moment-tensor,origin,phase-data,',
#     'nst': 99,
#     'dmin': 1.302,
#     'rms': 1.01,
#     'gap': 44,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 13 km NE of Mesariá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5717, 36.4687, 10]},
#    'id': 'us7000pcah'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '18 km NE of Firá, Greece',
#     'time': 1739003764033,
#     'updated': 1739005615040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pcac',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pcac&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000pcac',
#     'ids': ',us7000pcac,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 90,
#     'dmin': 1.363,
#     'rms': 1.35,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 18 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5957, 36.5272, 10]},
#    'id': 'us7000pcac'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '29 km NE of Firá, Greece',
#     'time': 1739002599857,
#     'updated': 1739004566040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pca9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pca9&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pca9',
#     'ids': ',us7000pca9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 39,
#     'dmin': 1.443,
#     'rms': 1.3,
#     'gap': 91,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 29 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6974, 36.5761, 10]},
#    'id': 'us7000pca9'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '25 km NE of Firá, Greece',
#     'time': 1738984284073,
#     'updated': 1739061805040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc8z',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc8z&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pc8z',
#     'ids': ',us7000pc8z,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': 1.412,
#     'rms': 1.14,
#     'gap': 104,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 25 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6606, 36.5562, 10]},
#    'id': 'us7000pc8z'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '20 km NE of Firá, Greece',
#     'time': 1738984114275,
#     'updated': 1739055201040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc8w',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc8w&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pc8w',
#     'ids': ',us7000pc8w,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 48,
#     'dmin': 1.386,
#     'rms': 0.94,
#     'gap': 89,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 20 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5881, 36.5559, 10]},
#    'id': 'us7000pc8w'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '27 km NE of Firá, Greece',
#     'time': 1738979523536,
#     'updated': 1738980898040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc8g',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc8g&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '7000pc8g',
#     'ids': ',us7000pc8g,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 72,
#     'dmin': 1.422,
#     'rms': 1.09,
#     'gap': 91,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 27 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6784, 36.561, 10]},
#    'id': 'us7000pc8g'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '24 km NE of Firá, Greece',
#     'time': 1738941410026,
#     'updated': 1738944608040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc4s',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc4s&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000pc4s',
#     'ids': ',us7000pc4s,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 1.42,
#     'rms': 1.01,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 24 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6218, 36.5805, 10]},
#    'id': 'us7000pc4s'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '12 km E of Mesariá, Greece',
#     'time': 1738924228046,
#     'updated': 1738930884040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc2q',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc2q&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000pc2q',
#     'ids': ',us7000pc2q,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 34,
#     'dmin': 1.258,
#     'rms': 1.36,
#     'gap': 88,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 12 km E of Mesariá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5828, 36.4155, 10]},
#    'id': 'us7000pc2q'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '22 km NE of Firá, Greece',
#     'time': 1738912575076,
#     'updated': 1739230563750,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc23',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc23&format=geojson',
#     'felt': 4,
#     'cdi': 6.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 403,
#     'net': 'us',
#     'code': '7000pc23',
#     'ids': ',us7000pc23,usauto7000pc23,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,internal-moment-tensor,origin,phase-data,',
#     'nst': 70,
#     'dmin': 1.39,
#     'rms': 1.06,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 22 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6196, 36.5485, 10]},
#    'id': 'us7000pc23'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '23 km NE of Firá, Greece',
#     'time': 1738912283084,
#     'updated': 1738919711040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc24',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc24&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pc24',
#     'ids': ',us7000pc24,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': 1.419,
#     'rms': 0.92,
#     'gap': 80,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 23 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5925, 36.5898, 10]},
#    'id': 'us7000pc24'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '7 km WNW of Royítika, Greece',
#     'time': 1738902267309,
#     'updated': 1738907333040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc0d',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc0d&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pc0d',
#     'ids': ',us7000pc0d,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 1.062,
#     'rms': 1.16,
#     'gap': 95,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 7 km WNW of Royítika, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [21.6053, 38.2116, 48.287]},
#    'id': 'us7000pc0d'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '10 km NE of Firá, Greece',
#     'time': 1738899333417,
#     'updated': 1738904899040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pc04',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pc04&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pc04',
#     'ids': ',us7000pc04,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 42,
#     'dmin': 1.3,
#     'rms': 0.94,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 10 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5198, 36.4858, 10]},
#    'id': 'us7000pc04'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '23 km NE of Firá, Greece',
#     'time': 1738870487442,
#     'updated': 1738939519040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbx6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbx6&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pbx6',
#     'ids': ',us7000pbx6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 65,
#     'dmin': 1.406,
#     'rms': 0.98,
#     'gap': 60,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 23 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6188, 36.5666, 10]},
#    'id': 'us7000pbx6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '12 km ENE of Firá, Greece',
#     'time': 1738865805225,
#     'updated': 1738875318737,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbwr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbwr&format=geojson',
#     'felt': 1,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 285,
#     'net': 'us',
#     'code': '7000pbwr',
#     'ids': ',us7000pbwr,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 60,
#     'dmin': 1.305,
#     'rms': 1.05,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 12 km ENE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5548, 36.4784, 10]},
#    'id': 'us7000pbwr'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '14 km ENE of Mesariá, Greece',
#     'time': 1738865019564,
#     'updated': 1738866192040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbw6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbw6&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000pbw6',
#     'ids': ',us7000pbw6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 1.293,
#     'rms': 0.71,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 14 km ENE of Mesariá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6043, 36.4463, 10]},
#    'id': 'us7000pbw6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '10 km NE of Firá, Greece',
#     'time': 1738850995259,
#     'updated': 1738937029040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbti',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbti&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pbti',
#     'ids': ',us7000pbti,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 1.3,
#     'rms': 0.91,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 10 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5025, 36.492, 10]},
#    'id': 'us7000pbti'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '22 km NE of Firá, Greece',
#     'time': 1738828664999,
#     'updated': 1738915196040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbs6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbs6&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pbs6',
#     'ids': ',us7000pbs6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': 1.385,
#     'rms': 0.87,
#     'gap': 107,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 22 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6349, 36.5371, 10]},
#    'id': 'us7000pbs6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '13 km NE of Firá, Greece',
#     'time': 1738822916994,
#     'updated': 1738826893040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbs0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbs0&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000pbs0',
#     'ids': ',us7000pbs0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': 1.332,
#     'rms': 0.74,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 13 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5284, 36.5171, 10]},
#    'id': 'us7000pbs0'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '11 km ENE of Oía, Greece',
#     'time': 1738821107409,
#     'updated': 1738822209040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbrr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbrr&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000pbrr',
#     'ids': ',us7000pbrr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 55,
#     'dmin': 1.322,
#     'rms': 1.29,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 11 km ENE of Oía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.4862, 36.5204, 10]},
#    'id': 'us7000pbrr'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '27 km NE of Firá, Greece',
#     'time': 1738814898340,
#     'updated': 1738815800040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbr0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbr0&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000pbr0',
#     'ids': ',us7000pbr0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 1.428,
#     'rms': 0.59,
#     'gap': 106,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 27 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6683, 36.5714, 10]},
#    'id': 'us7000pbr0'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '17 km NE of Firá, Greece',
#     'time': 1738813000735,
#     'updated': 1738813918040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbqv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbqv&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pbqv',
#     'ids': ',us7000pbqv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': 1.36,
#     'rms': 0.99,
#     'gap': 106,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 17 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5755, 36.5315, 10]},
#    'id': 'us7000pbqv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '17 km NE of Firá, Greece',
#     'time': 1738812831642,
#     'updated': 1738813465040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbqt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbqt&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000pbqt',
#     'ids': ',us7000pbqt,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 34,
#     'dmin': 1.355,
#     'rms': 0.8,
#     'gap': 106,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 17 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5669, 36.5289, 10]},
#    'id': 'us7000pbqt'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '20 km NE of Oía, Greece',
#     'time': 1738812535539,
#     'updated': 1738814729040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbqr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbqr&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pbqr',
#     'ids': ',us7000pbqr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 1.393,
#     'rms': 0.82,
#     'gap': 103,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 20 km NE of Oía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5527, 36.5757, 10]},
#    'id': 'us7000pbqr'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '29 km NE of Oía, Greece',
#     'time': 1738812188345,
#     'updated': 1738813094040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbqp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbqp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000pbqp',
#     'ids': ',us7000pbqp,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 55,
#     'dmin': 1.477,
#     'rms': 0.91,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 29 km NE of Oía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.6136, 36.6462, 10]},
#    'id': 'us7000pbqp'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '13 km NE of Firá, Greece',
#     'time': 1738811955233,
#     'updated': 1738814320040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000pbqw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000pbqw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000pbqw',
#     'ids': ',us7000pbqw,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 25,
#     'dmin': 1.326,
#     'rms': 0.97,
#     'gap': 81,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 13 km NE of Firá, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.5265, 36.5114, 10]},
#    'id': 'us7000pbqw'},
#   {'type': 'Feature',
# ...
#    'id': 'us6000npt3'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '19 km SW of Paphos, Cyprus',
#     'time': 1725398992079,
#     'updated': 1733339379228,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000npk6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000npk6&format=geojson',
#     'felt': 156,
#     'cdi': 5,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 447,
#     'net': 'us',
#     'code': '6000npk6',
#     'ids': ',us6000npk6,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 178,
#     'dmin': 0.931,
#     'rms': 0.76,
#     'gap': 52,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 19 km SW of Paphos, Cyprus'},
#    'geometry': {'type': 'Point', 'coordinates': [32.2557, 34.6708, 17.392]},
#    'id': 'us6000npk6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '23 km WNW of Itháki, Greece',
#     'time': 1725265368442,
#     'updated': 1731687587040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000np7t',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000np7t&format=geojson',
#     'felt': 4,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 260,
#     'net': 'us',
#     'code': '6000np7t',
#     'ids': ',us6000np7t,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 34,
#     'dmin': 1.561,
#     'rms': 0.35,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 23 km WNW of Itháki, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [20.4723, 38.4595, 38.852]},
#    'id': 'us6000np7t'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '11 km SSE of Áno Kastrítsi, Greece',
#     'time': 1724877721758,
#     'updated': 1731187117040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nnc9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000nnc9&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000nnc9',
#     'ids': ',us6000nnc9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': 0.906,
#     'rms': 0.96,
#     'gap': 86,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 11 km SSE of Áno Kastrítsi, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [21.902, 38.1799, 59.766]},
#    'id': 'us6000nnc9'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '21 km SSE of Chóra Sfakíon, Greece',
#     'time': 1724863667783,
#     'updated': 1731187164040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000ngdi',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ngdi&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000ngdi',
#     'ids': ',us7000ngdi,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.613,
#     'rms': 1.21,
#     'gap': 240,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 21 km SSE of Chóra Sfakíon, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [24.2146, 35.0227, 42.929]},
#    'id': 'us7000ngdi'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '13 km NE of Kastrí, Greece',
#     'time': 1724862597573,
#     'updated': 1731187115040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nn9g',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000nn9g&format=geojson',
#     'felt': 35,
#     'cdi': 3.9,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 414,
#     'net': 'us',
#     'code': '6000nn9g',
#     'ids': ',us6000nn9g,usauto6000nn9g,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,',
#     'nst': 247,
#     'dmin': 0.675,
#     'rms': 0.83,
#     'gap': 77,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 13 km NE of Kastrí, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [24.2038, 34.9142, 54.834]},
#    'id': 'us6000nn9g'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '25 km NNE of Cariati, Italy',
#     'time': 1724762864174,
#     'updated': 1731187109040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nn1z',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000nn1z&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000nn1z',
#     'ids': ',us6000nn1z,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 77,
#     'dmin': 0.998,
#     'rms': 0.49,
#     'gap': 85,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 25 km NNE of Cariati, Italy'},
#    'geometry': {'type': 'Point', 'coordinates': [17.0972, 39.697, 10]},
#    'id': 'us6000nn1z'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '18 km E of Istiaía, Greece',
#     'time': 1724702023681,
#     'updated': 1731187104040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nmxi',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000nmxi&format=geojson',
#     'felt': 50,
#     'cdi': 4.5,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 348,
#     'net': 'us',
#     'code': '6000nmxi',
#     'ids': ',us6000nmxi,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': 78,
#     'dmin': 0.806,
#     'rms': 0.66,
#     'gap': 36,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 18 km E of Istiaía, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [23.3657, 38.9494, 10]},
#    'id': 'us6000nmxi'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '9 km NNW of Kastrí, Greece',
#     'time': 1724639928392,
#     'updated': 1731187156040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000ngc3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ngc3&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000ngc3',
#     'ids': ',us7000ngc3,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.793,
#     'rms': 0.81,
#     'gap': 189,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 9 km NNW of Kastrí, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [24.0378, 34.9124, 49.686]},
#    'id': 'us7000ngc3'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '19 km WSW of Kastrí, Greece',
#     'time': 1724639848057,
#     'updated': 1731187155040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000ngc2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ngc2&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000ngc2',
#     'ids': ',us7000ngc2,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.973,
#     'rms': 0.68,
#     'gap': 137,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 19 km WSW of Kastrí, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [23.9097, 34.7387, 10]},
#    'id': 'us7000ngc2'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '12 km E of Ouranoupolis, Greece',
#     'time': 1724529266959,
#     'updated': 1730582941040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n984',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n984&format=geojson',
#     'felt': 11,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 302,
#     'net': 'us',
#     'code': '7000n984',
#     'ids': ',us7000n984,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': 59,
#     'dmin': 1.277,
#     'rms': 1,
#     'gap': 36,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 12 km E of Ouranoupolis, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [24.1291, 40.334, 19.667]},
#    'id': 'us7000n984'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '32 km N of Astypálaia, Greece',
#     'time': 1724398093194,
#     'updated': 1730582979040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000ngam',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ngam&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000ngam',
#     'ids': ',us7000ngam,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 1.518,
#     'rms': 1.18,
#     'gap': 61,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 32 km N of Astypálaia, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [26.4035, 36.8389, 9.859]},
#    'id': 'us7000ngam'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '35 km ENE of Karpathos, Greece',
#     'time': 1724285964316,
#     'updated': 1730582922040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n8kt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n8kt&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000n8kt',
#     'ids': ',us7000n8kt,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 56,
#     'dmin': 0.722,
#     'rms': 0.62,
#     'gap': 112,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 35 km ENE of Karpathos, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [27.5603, 35.6516, 13.952]},
#    'id': 'us7000n8kt'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.9,
#     'place': '14 km SW of Eresós, Greece',
#     'time': 1724225729390,
#     'updated': 1730582915040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n8f9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n8f9&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 234,
#     'net': 'us',
#     'code': '7000n8f9',
#     'ids': ',us7000n8f9,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 28,
#     'dmin': 0.856,
#     'rms': 0.84,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.9 - 14 km SW of Eresós, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.8051, 39.0838, 10]},
#    'id': 'us7000n8f9'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.7,
#     'place': '6 km E of Kırıkhan, Turkey',
#     'time': 1724115461872,
#     'updated': 1730582907040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n81t',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n81t&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 211,
#     'net': 'us',
#     'code': '7000n81t',
#     'ids': ',us7000n81t,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.745,
#     'rms': 0.7,
#     'gap': 52,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 6 km E of Kırıkhan, Turkey'},
#    'geometry': {'type': 'Point', 'coordinates': [36.428, 36.503, 10]},
#    'id': 'us7000n81t'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '9 km ESE of Karlıova, Turkey',
#     'time': 1724004919934,
#     'updated': 1729957774040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n7tp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n7tp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000n7tp',
#     'ids': ',us7000n7tp,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 44,
#     'dmin': 0.886,
#     'rms': 0.52,
#     'gap': 36,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 9 km ESE of Karlıova, Turkey'},
#    'geometry': {'type': 'Point', 'coordinates': [41.1155, 39.2699, 10]},
#    'id': 'us7000n7tp'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '69 km WSW of Katastárion, Greece',
#     'time': 1723919563348,
#     'updated': 1729957758040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n7n2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n7n2&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000n7n2',
#     'ids': ',us7000n7n2,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 30,
#     'dmin': 1.619,
#     'rms': 1.29,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 69 km WSW of Katastárion, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [19.9933, 37.6849, 10]},
#    'id': 'us7000n7n2'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '5 km NNW of As Salamīyah, Syria',
#     'time': 1723803336916,
#     'updated': 1729957740040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000n7dh',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000n7dh&format=geojson',
#     'felt': 15,
#     'cdi': 4.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 361,
#     'net': 'us',
#     'code': '7000n7dh',
#     'ids': ',us7000n7dh,usauto7000n7dh,',
#     'sources': ',us,usauto,',
#     'types': ',dyfi,impact-text,internal-moment-tensor,moment-tensor,origin,phase-data,',
#     'nst': 131,
#     'dmin': 2.113,
#     'rms': 0.39,
#     'gap': 65,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 5 km NNW of As Salamīyah, Syria'},
#    'geometry': {'type': 'Point', 'coordinates': [37.0338, 35.0598, 10]},
#    'id': 'us7000n7dh'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '65 km SE of Neftçala, Azerbaijan',
#     'time': 1723695753461,
#     'updated': 1729957693040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nq3g',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000nq3g&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000nq3g',
#     'ids': ',us6000nq3g,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.591,
#     'rms': 1.26,
#     'gap': 88,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 65 km SE of Neftçala, Azerbaijan'},
#    'geometry': {'type': 'Point', 'coordinates': [49.879, 39.044, 10]},
#    'id': 'us6000nq3g'}],
#  'bbox': [17.0972, 26.9879, 4.096, 50.2266, 45.5663, 150.935]}

# %%
# 1. Access the metadata:
metadata = dataset['metadata']
print(f"Data source: {metadata['title']}")
print(f"Number of earthquakes: {metadata['count']}")
# Out:
# Data source: USGS Earthquakes
# Number of earthquakes: 286

# %%
# 2. Access the list of features:
earthquakes = dataset['features']

# %%
# 3. Create lists to store the extracted data
magnitudes = []
places = []
longitudes = []
latitudes = []
depths = []
timestamps = []

# %%
# 4. Iterate through the earthquakes and extract information:
for earthquake in earthquakes:
    properties = earthquake['properties']
    geometry = earthquake['geometry']
    magnitude = properties['mag']
    place = properties['place']
    longitude, latitude, depth = geometry['coordinates']  # Unpack the coordinates
    timestamp_ms = properties['time']

    # Convert timestamp to datetime object (it's in milliseconds)
    import datetime
    timestamp = datetime.datetime.fromtimestamp(timestamp_ms / 1000)

    magnitudes.append(magnitude)
    places.append(place)
    longitudes.append(longitude)
    latitudes.append(latitude)
    depths.append(depth)
    timestamps.append(timestamp)

# %%
# Creating a Pandas DataFrame so we can use Pandas library for analysis
data = {
    'Magnitude': magnitudes,
    'Place': places,
    'Longitude': longitudes,
    'Latitude': latitudes,
    'Depth': depths,
    'Timestamp': timestamps
}
df = pd.DataFrame(data)
df.head()
# Out:
#    Magnitude                        Place  Longitude  Latitude  Depth               Timestamp
# 0      4.000  24 km SW of Amorgós, Greece     25.678    36.704 10.000 2025-02-11 13:46:48.807
# 1      4.200       20 km E of Íos, Greece     25.509    36.693 10.000 2025-02-11 09:51:04.290
# 2      5.100      28 km NE of Oía, Greece     25.621    36.632 10.000 2025-02-11 09:37:24.695
# 3      4.100  24 km SW of Amorgós, Greece     25.738    36.655 10.000 2025-02-11 08:37:35.759
# 4      5.200  25 km SW of Amorgós, Greece     25.676    36.694 10.000 2025-02-11 07:16:28.890

# %%
# Would like to use the folium library to visualise earthquakes that happened around the Santorini and surrounds. Turkey had a major earthquake in 2023, I also wanted see the activity in Turkey region as well.

turkey_coord = [39, 35]
turkey_map_normal = folium.Map(location=turkey_coord, zoom_start=5.5)
HeatMap(data=df[['Latitude', 'Longitude', 'Magnitude']], radius=15).add_to(turkey_map_normal)

for index, row in df.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=row['Magnitude']/2,
        color='red',
        fill_color='red').add_to(turkey_map_normal)

turkey_map_normal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76952a90d03ce6e5d23b3397fd8b093c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76952a90d03ce6e5d23b3397fd8b093c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76952a90d03ce6e5d23b3397fd8b093c = L.map(
#                 &quot;map_76952a90d03ce6e5d23b3397fd8b093c&quot;,
#                 {
#                     center: [39.0, 35.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d67792e14541173b03c1919b31cd8729 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d67792e14541173b03c1919b31cd8729.addTo(map_76952a90d03ce6e5d23b3397fd8b093c);
#
#
#             var heat_map_f70e4953a56ee40cab1b3913d8d1f3fb = L.heatLayer(
#                 [[36.7038, 25.6781, 4.0], [36.6927, 25.5085, 4.2], [36.6318, 25.6213, 5.1], [36.6549, 25.7381, 4.1], [36.6944, 25.6758, 5.2], [36.6065, 25.6911, 4.3], [36.6826, 25.6831, 4.8], [36.6094, 25.6436, 4.0], [35.2608, 22.1926, 4.2], [36.626, 25.5758, 4.3], [36.5372, 25.5565, 4.4], [36.5585, 25.6002, 4.3], [36.4461, 25.5708, 4.7], [36.5236, 25.5065, 4.6], [36.6992, 25.6236, 5.2], [36.3749, 25.5003, 4.7], [36.5316, 25.5896, 4.3], [36.5546, 25.6596, 4.2], [36.5178, 25.6341, 4.4], [36.5754, 25.6324, 4.2], [36.6225, 25.5453, 4.3], [36.5667, 25.6761, 4.2], [36.4382, 25.5586, 4.0], [36.4771, 25.4747, 4.5], [36.5816, 25.6139, 4.4], [36.5782, 25.6735, 4.1], [36.6788, 25.6277, 4.3], [36.3756, 25.4977, 4.6], [36.3919, 25.6486, 4.2], [36.5418, 25.5645, 4.4], [36.4687, 25.5717, 5.1], [36.5272, 25.5957, 4.9], [36.5761, 25.6974, 4.2], [36.5562, 25.6606, 4.4], [36.5559, 25.5881, 4.3], [36.561, 25.6784, 4.8], [36.5805, 25.6218, 4.6], [36.4155, 25.5828, 4.1], [36.5485, 25.6196, 5.1], [36.5898, 25.5925, 4.4], [38.2116, 21.6053, 4.2], [36.4858, 25.5198, 4.3], [36.5666, 25.6188, 4.4], [36.4784, 25.5548, 4.3], [36.4463, 25.6043, 4.1], [36.492, 25.5025, 4.4], [36.5371, 
], [36.5404, 25.5565, 4.3], [35.1385, 21.2746, 4.4], [38.4731, 24.0614, 4.4], [35.4736, 22.1174, 4.2], [36.1942, 22.0194, 4.0], [34.9391, 24.4723, 4.0], [34.4787, 45.4863, 4.8], [37.2524, 21.6094, 4.2], [41.8275, 19.3376, 4.3], [39.4549, 26.2835, 5.0], [44.687, 36.608, 4.5], [43.6238, 39.8338, 3.1], [36.0441, 35.984, 4.2], [34.407, 46.0157, 4.2], [37.5394, 45.5344, 4.0], [39.9033, 41.7608, 4.6], [37.4422, 21.7498, 4.0], [37.2692, 21.5571, 4.9], [36.5503, 26.8011, 4.

# %%
# I would like to add a new column called "Country" to see if I can use it for some aggregations. First, I'll create a function to split the text for me 

def extract_country(place_string):
    """
    Extracts the country name from a place string like "28 km NE of Firá, Greece".
    Handles cases where the string might be in a different format.
    """
    try:
        country = place_string.split(', ')[-1]  # Split at ", " and take the last part
        return country
    except IndexError:
        return "Unknown"  # Handle cases without a comma
    except:
        return "Error"  # Catch other potential errors

# %%
# Apply the function to the 'Place' column to create a new 'Country' column
df['Country'] = df['Place'].apply(extract_country)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Magnitude  286 non-null    float64
#  1   Place      286 non-null    object
#  2   Longitude  286 non-null    float64
#  3   Latitude   286 non-null    float64
#  4   Depth      286 non-null    float64
#  5   Timestamp  286 non-null    datetime64[ns]
#  6   Country    286 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 15.8+ KB

# %%
df.head()
# Out:
#    Magnitude                        Place  Longitude  Latitude  Depth               Timestamp Country
# 0      4.000  24 km SW of Amorgós, Greece     25.678    36.704 10.000 2025-02-11 13:46:48.807  Greece
# 1      4.200       20 km E of Íos, Greece     25.509    36.693 10.000 2025-02-11 09:51:04.290  Greece
# 2      5.100      28 km NE of Oía, Greece     25.621    36.632 10.000 2025-02-11 09:37:24.695  Greece
# 3      4.100  24 km SW of Amorgós, Greece     25.738    36.655 10.000 2025-02-11 08:37:35.759  Greece
# 4      5.200  25 km SW of Amorgós, Greece     25.676    36.694 10.000 2025-02-11 07:16:28.890  Greece

# %%
df.groupby("Country")['Magnitude'].agg(['min', 'max', 'count'])
# Out:
#                          min   max  count
# Country
# Albania                3.800 4.100      4
# Armenia                4.400 4.400      1
# Azerbaijan             3.900 4.400      4
# Bosnia and Herzegovina 4.100 4.100      1
# Cyprus                 4.000 4.900      6
# Egypt                  4.200 4.400      3
# Georgia                3.600 4.100      2
# Greece                 3.900 5.300    208
# Iran                   4.000 4.800      6
# Iraq                   4.000 4.300      2
# Italy                  4.400 4.400      1
# Kosovo                 4.300 4.300      1
# Libya                  4.000 4.000      1
# Montenegro             4.300 4.300      1
# Romania                4.400 5.200      2
# Russia                 3.100 3.900      2
# Syria                  4.800 4.800      1
# Turkey                 3.700 6.000     39
# Ukraine                4.500 4.500      1

# %%
#?df.groupby

# %% [markdown]
# ## Some feature engineering

# %%
# Extracting some date-time features to be used for aggregations

# Extract the Month
df['Month'] = df['Timestamp'].dt.month_name() 

# Extract the Hour to create 'TimeOfDay'
df['Hour'] = df['Timestamp'].dt.hour

# %%
# Want to create this function to create a new column which would show the time of the day
def categorize_time(hour):
    """Categorizes the hour of the day into Morning, Afternoon, Evening, or Night."""
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 24:
        return 'Evening'
    else:
        return 'Night'  # Covers 0-6

# %%
df['TimeOfDay'] = df['Hour'].apply(categorize_time)

# %%
df.head()
# Out:
#    Magnitude                        Place  Longitude  Latitude  Depth               Timestamp Country     Month  Hour  TimeOfDay
# 0      4.000  24 km SW of Amorgós, Greece     25.678    36.704 10.000 2025-02-11 13:46:48.807  Greece  February    13  Afternoon
# 1      4.200       20 km E of Íos, Greece     25.509    36.693 10.000 2025-02-11 09:51:04.290  Greece  February     9    Morning
# 2      5.100      28 km NE of Oía, Greece     25.621    36.632 10.000 2025-02-11 09:37:24.695  Greece  February     9    Morning
# 3      4.100  24 km SW of Amorgós, Greece     25.738    36.655 10.000 2025-02-11 08:37:35.759  Greece  February     8    Morning
# 4      5.200  25 km SW of Amorgós, Greece     25.676    36.694 10.000 2025-02-11 07:16:28.890  Greece  February     7    Morning

# %%
# Most frequent month for earthquakes - February 2025 was the highest amount of earthquakes
monthly_counts = df['Month'].value_counts()
print("\nEarthquake counts per month:")
print(monthly_counts)
# Out:
# Earthquake counts per month:
# Month
# February     140
# October       32
# December      28
# September     26
# November      23
# January       21
# August        16
# Name: count, dtype: int64

# %%
# Most frequent time of day for earthquakes - Evening time is when the earthquakes happen more 
time_of_day_counts = df['TimeOfDay'].value_counts()
print("\nEarthquake counts per time of day:")
print(time_of_day_counts)
# Out:
# Earthquake counts per time of day:
# TimeOfDay
# Evening      89
# Afternoon    76
# Morning      61
# Night        60
# Name: count, dtype: int64

# %%
# Some descriptive insights from the depth column
df['Depth'].describe()
# Out:
# count   286.000
# mean     17.058
# std      20.431
# min       4.096
# 25%      10.000
# 50%      10.000
# 75%      10.000
# max     150.935
# Name: Depth, dtype: float64

# %% [markdown]
# ## Want to create some visualisations, such as line plots and folium maps

# %%
# Changing the index to the Timestamp column which would then allow us to plot some line charts
df_time = df.set_index("Timestamp")
df_time.head()
# Out:
#                          Magnitude                        Place  Longitude  Latitude  Depth Country     Month  Hour  TimeOfDay
# Timestamp
# 2025-02-11 13:46:48.807      4.000  24 km SW of Amorgós, Greece     25.678    36.704 10.000  Greece  February    13  Afternoon
# 2025-02-11 09:51:04.290      4.200       20 km E of Íos, Greece     25.509    36.693 10.000  Greece  February     9    Morning
# 2025-02-11 09:37:24.695      5.100      28 km NE of Oía, Greece     25.621    36.632 10.000  Greece  February     9    Morning
# 2025-02-11 08:37:35.759      4.100  24 km SW of Amorgós, Greece     25.738    36.655 10.000  Greece  February     8    Morning
# 2025-02-11 07:16:28.890      5.200  25 km SW of Amorgós, Greece     25.676    36.694 10.000  Greece  February     7    Morning

# %%
import matplotlib.pyplot as plt
#fig, ax = plt.subplots()
df_time.resample('D').size().plot()  # Counts the number of events per day
plt.xticks(rotation=45)
plt.show()

# %%
# It seems like there is a lot of activity in February, so let's zoom in a bit more

# 130      4.400   30 km SW of Amorgós, Greece     25.644    36.651 10.000 2025-02-02 22:41:27.533  Greece  February    22    Evening
# 131      4.400      27 km NE of Firá, Greece     25.621    36.619 10.000 2025-02-02 22:35:33.942  Greece  February    22    Evening
# 132      4.400      25 km NE of Firá, Greece     25.616    36.591 10.000 2025-02-02 22:04:14.837  Greece  February    22    Evening
# 133      4.200      20 km NE of Firá, Greece     25.572    36.569 10.000 2025-02-02 20:14:22.736  Greece  February    20    Evening
# 134      4.100      21 km NE of Firá, Greece     25.597    36.560 10.000 2025-02-02 19:37:03.904  Greece  February    19    Evening
# 135      4.600       27 km NE of Oía, Greece     25.593    36.643 10.000 2025-02-02 18:22:05.306  Greece  February    18    Evening
# 138      4.200  21 km ENE of Mesariá, Greece     25.660    36.492 10.000 2025-02-01 23:51:44.809  Greece  February    23    Evening
# 139      4.300      17 km NE of Firá, Greece     25.556    36.540 10.000 2025-02-01 16:31:34.509  Greece  February    16  Afternoon

# %%
# Now I would like to zoom in to the Greece region on a Folium map, tooltips showing the date and the magnitute of the earthquake
from folium.plugins import MarkerCluster

# Create a base map centered on Greece
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=8)

# Add individual markers
for _, row in df_top_places.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Place: {row['Place']}<br>Magnitude: {row['Magnitude']}<br>Timestamp: {row['Timestamp']}",
        tooltip=f"Date: {row['Timestamp'].strftime('%Y-%m-%d %H:%M:%S')} | Mag: {row['Magnitude']}"  # Tooltip shows date & magnitude
    ).add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db3404f4a44dd1c58a7a2af466d1b550 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db3404f4a44dd1c58a7a2af466d1b550&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db3404f4a44dd1c58a7a2af466d1b550 = L.map(
#                 &quot;map_db3404f4a44dd1c58a7a2af466d1b550&quot;,
#                 {
#                     center: [37.12444160839161, 28.004460839160842],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b1840a628b35bdbff9ccf152da5cbe5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b1840a628b35bdbff9ccf152da5cbe5.addTo(map_db3404f4a44dd1c58a7a2af466d1b550);
#
#
#             var marker_1edee4ef76f2d4ab4e0ea8d1482a96c6 = L.marker(
#                 [36.7038, 25.6781],
#                 {}
#             ).addTo(map_db3404f4a44dd1c58a7a2af466d1b550);
#
#
#         var popup_ee6cf55f2495e1e55972e3f77178a99b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35b702e024ceca0a02819f3d1b876131 = $(`&lt;div id=&quot;html_35b702e024ceca0a02819f3d1b876131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Place: 24 km SW of Amorgós, Greece&lt;br&gt;Magnitude: 4.0&lt;br&gt;Timestamp: 2025-02-11 13:46:48.807000&lt;/div&gt;`)[0];
#                 popup_ee6cf55f2495e1e55972e3f77178a99b.setContent(html_35b702e024ceca0a02819f3d1b876131);
#
#
#
#         marker_1edee4ef76f2d4ab4e0ea8d1482a96c6.bindPopup(popup_ee6cf55f2495e1e55972e3f77178a99b)
#         ;
#
#
#
#
#             marker_1edee4ef76f2d4ab4e0ea8d1482a96c6.bindTooltip(
#                 `&lt;div&gt;
#                      Date: 2025-02-11 13:46:48 | Mag: 4.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_35371caa2402a7a539e21538d58d6fc6 = L.marker(
#                 [36.6549, 25.7381],
#                 {}
#             ).addTo(map_db3404f4a44dd1c58a7a2af466d1b550);
#
#
#         var popup_4413586fb920c23869601e4bcc5de3b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59619b50a30be1b07ba96cabe27082a6 = $(`&lt;div id=&quot;html_59619b50a30be1b07ba96cabe27082a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Place: 24 km SW of Amorgós, Greece&lt;br&gt;Magnitude: 4.1&lt;br&gt;Timestamp: 2025-02-11 08:37:35.759000&lt;/div&gt;`)[0];
#                 popup_4413586fb920c23869601e4bcc5de3b2.setContent(html_59619b50a30be1b07ba96cabe27082a6);
#
#
#
#         marker_35371caa2402a7a539e21538d58d6fc6.bindPopup(popup_4413586fb920c23869601e4bcc5de3b2)
#         ;
#
#
#
#
#             marker_35371caa2402a7a539e21538d58d6fc6.bindTooltip(
#                 `&lt;div&gt;
#                      Date: 2025-02-11 08:37:35 | Mag: 4.1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3f0fd7f6a26a5a98ec4e831598687e93 = L.marker(
#                 [36.6094, 25.6436],
#                 {}
#             ).addTo(map_db3404f4a44dd1c58a7a2af466d1b550);
#
#
#         var popup_1db421f0331c945e326ada498269c3f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b52362a339b87684d99d376015c132dd = $(`&lt;div id=&quot;html_b52362a339b87684d99d376015c132dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Place: 28 km NE of Firá, Greece&lt;br&gt;Magnitude: 4.0&lt;br&gt;Timestamp: 2025-02-10 12:00:00.958000&lt;/div&gt;`)[0];
#                 popup_1db421f0331c945e326ada498269c3f7.setContent(html_b52362a339b87684d99d376015c132dd);
#
#
#
#         marker_3f0fd7f6a26a5a98ec4e831598687e93.bindPopup(popup_1db421f0331c945e326ada498269c3f7)
#         ;
#
#
#
#
#             marker_3f0fd7f6a26a5a98ec4e831598687e93.bindTooltip(
#                 `&lt;div&gt;
#                      Date: 2025-02-10 12:00:00 | Mag: 4.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_937b16a07bc58530a5e770145d682791 = L.marker(
#                 [36.5372, 25.5565],
#                 {}
#             ).addTo(map_db3404f4a44dd1c58a7a2af466d1b550);
#
#
#         var popup_10935152eddb5804f74e53bf578cffab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d19b11b2c24c9ae384fd0272860c9389 = $(`&lt;div id=&quot;html_d19b11b2c24c9ae384fd0272860c9389&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Place: 17 km NE of Firá, Greece&lt;br&gt;Magnitude: 4.4&lt;br&gt;Timestamp: 2025-02-10 06:31:39.901000&lt;/div&gt;`)[0];
#                 popup_10935152eddb5804f74e53bf578cffab.setContent(html_d19b11b2c24c9ae384fd0272860c9389)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Magnitude  286 non-null    float64
#  1   Place      286 non-null    object
#  2   Longitude  286 non-null    float64
#  3   Latitude   286 non-null    float64
#  4   Depth      286 non-null    float64
#  5   Timestamp  286 non-null    datetime64[ns]
#  6   Country    286 non-null    object
#  7   Month      286 non-null    object
#  8   Hour       286 non-null    int32
#  9   TimeOfDay  286 non-null    object
# dtypes: datetime64[ns](1), float64(4), int32(1), object(4)
# memory usage: 21.4+ KB

# %% [markdown]
# ## Conclusion:
#
# It seems like there is a lot happening in the same region of Greece. I would like to retreive more data and build a machine learning model to predict potential earthquakes in future.
